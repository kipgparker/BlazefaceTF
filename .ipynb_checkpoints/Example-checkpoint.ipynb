# %%
import blazeface
blazeface = blazeface.BlazeFace()

# %%
import matplotlib.pyplot as plt
import numpy as np

img = np.expand_dims(plt.imread('Lenna.png'), axis = 0)
prediction = blazeface.predict(img)
print(prediction)
# Out:
# tf.Tensor([], shape=(0, 4), dtype=float32)
